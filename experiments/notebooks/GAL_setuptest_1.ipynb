# %%
# ===========================
# 🔒 クローズドGitHubリポジトリをColabでcloneするテンプレート
# ===========================

from getpass import getpass
import os

# ① GitHubユーザー名とリポジトリ名を入力
GITHUB_USER = "miyauchikazuyoshi"
REPO_NAME   = "InsightSpike-AI"

# ② 個人アクセストークンを入力（画面には表示されません）
GITHUB_TOKEN = getpass('GitHub Personal Access Tokenを入力してください: ')
REPO_URL = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"

# !git clone $REPO_URL

#  cloneしたディレクトリに移動（必要なら）
# %cd $REPO_NAME

# 以降は通常通りpythonやnotebookを実行
# 例: !python demo.py
# Out:
# GitHub Personal Access Tokenを入力してください: ··········
# Cloning into 'InsightSpike-AI'...
# remote: Enumerating objects: 2873, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 2873 (delta 54), reused 97 (delta 37), pack-reused 2715 (from 1)
# Receiving objects: 100% (2873/2873), 14.33 MiB | 8.78 MiB/s, done.
# Resolving deltas: 100% (1418/1418), done.
# /content/InsightSpike-AI

# %%
# スクリプトに実行権限を付与
# !chmod +x scripts/colab/setup_colab.sh

# 作成したセットアップスクリプトを実行！
# これで必要なものがすべて、正しい順番でインストールされます。
# !scripts/colab/setup_colab.sh
# Out:
# Installing and configuring Poetry...
# Removing existing poetry.lock to ensure a fresh dependency resolution for Colab...
# Installing dependencies with Poetry and generating a new lock file...
# Skipping virtualenv creation, as specified in config file.
# Updating dependencies
# Resolving dependencies... (13.0s)
#
# Package operations: 26 installs, 46 updates, 0 removals
#
#   - Updating traitlets (5.7.1 -> 5.14.3): Pending...
#   - Installing types-python-dateutil (2.9.0.20250516): Pending...
#   - Installing types-python-dateutil (2.9.0.20250516): Downloading... 0%
#   - Installing types-python-dateutil (2.9.0.20250516): Downloading... 0%
#   - Updating traitlets (5.7.1 -> 5.14.3): Downloading... 0%
#   - Installing types-python-dateutil (2.9.0.20250516): Downloading... 0%
#   - Installing types-python-dateutil (2.9.0.20250516): Downloading... 100%
#   - Installing types-python-dateutil (2.9.0.20250516): Installing...
#   - Installing types-python-dateutil (2.9.0.20250516)
#   - Installing types-python-dateutil (2.9.0.20250516)
#   - Updating traitlets (5.7.1 -> 5.14.3): Downloading... 100%
#   - Installing types-python-dateutil (2.9.0.20250516)
#   - Installing types-python-dateutil (2.9.0.20250516)
#   - Updating traitlets (5.7.1 -> 5.14.3): Installing...
#   - Installing types-python-dateutil (2.9.0.20250516)
#   - Installing types-python-dateutil (2.9.0.20250516)
#   - Updating traitlets (5.7.1 -> 5.14.3)
#   - Installing types-python-dateutil (2.9.0.20250516)
#   - Installing arrow (1.3.0): Pending...
#   - Updating pyzmq (24.0.1 -> 27.0.0): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Updating pyzmq (24.0.1 -> 27.0.0): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Installing arrow (1.3.0): Downloading... 0%
#   - Updating pyzmq (24.0.1 -> 27.0.0): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Updating pyzmq (24.0.1 -> 27.0.0): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Installing arrow (1.3.0): Downloading... 100%
#   - Updating pyzmq (24.0.1 -> 27.0.0): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Updating pyzmq (24.0.1 -> 27.0.0): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Installing arrow (1.3.0): Installing...
#   - Updating pyzmq (24.0.1 -> 27.0.0): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Updating pyzmq (24.0.1 -> 27.0.0): Downloading... 0%
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Updating pyzmq (24.0.1 -> 27.0.0): Downloading... 0%
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Installing arrow (1.3.0)
#   - Updating pyzmq (24.0.1 -> 27.0.0): Downloading... 0%
#   - Updating tornado (6.4.2 -> 6.5.1): Pending...
#   - Updating tornado (6.4.2 -> 6.5.1): Downloading... 0%
#   - Updating tornado (6.4.2 -> 6.5.1): Downloading... 0%
#   - Updating pyzmq (24.0.1 -> 27.0.0): Downloading... 100%
#   - Updating tornado (6.4.2 -> 6.5.1): Downloading... 0%
#   - Updating tornado (6.4.2 -> 6.5.1): Downloading... 0%
#   - Updating pyzmq (24.0.1 -> 27.0.0): Installing...
#   - Updating tornado (6.4.2 -> 6.5.1): Downloading... 0%
#   - Updating tornado (6.4.2 -> 6.5.1): Downloading... 100%
#   - Updating tornado (6.4.2 -> 6.5.1): Installing...
#   - Updating tornado (6.4.2 -> 6.5.1)
#   - Updating tornado (6.4.2 -> 6.5.1)
#   - Updating pyzmq (24.0.1 -> 27.0.0)
#   - Updating tornado (6.4.2 -> 6.5.1)
#   - Installing fqdn (1.5.1): Pending...
#   - Installing isoduration (20.11.0): Pending...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Pending...
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Pending...
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing isoduration (20.11.0): Downloading... 0%
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Pending...
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 0%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 0%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing isoduration (20.11.0): Downloading... 100%
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 0%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing isoduration (20.11.0): Downloading... 100%
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 0%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing fqdn (1.5.1): Downloading... 0%
#   - Installing isoduration (20.11.0): Downloading... 100%
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 0%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing isoduration (20.11.0): Installing...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing isoduration (20.11.0): Installing...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing fqdn (1.5.1): Downloading... 100%
#   - Installing isoduration (20.11.0): Installing...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing isoduration (20.11.0): Installing...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing fqdn (1.5.1): Installing...
#   - Installing isoduration (20.11.0): Installing...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing isoduration (20.11.0): Installing...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing fqdn (1.5.1)
#   - Installing isoduration (20.11.0): Installing...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Downloading... 100%
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Installing...
#   - Installing rfc3339-validator (0.1.4): Pending...
#   - Installing rfc3986-validator (0.1.1): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing rfc3986-validator (0.1.1): Downloading... 0%
#   - Installing uri-template (1.3.0): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing rfc3986-validator (0.1.1): Downloading... 100%
#   - Installing uri-template (1.3.0): Pending...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing rfc3986-validator (0.1.1): Installing...
#   - Installing uri-template (1.3.0): Pending...
#   - Installing uri-template (1.3.0): Downloading... 0%
#   - Installing uri-template (1.3.0): Downloading... 100%
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3986-validator (0.1.1): Installing...
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3339-validator (0.1.4): Downloading... 0%
#   - Installing rfc3986-validator (0.1.1): Installing...
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3986-validator (0.1.1): Installing...
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3339-validator (0.1.4): Downloading... 100%
#   - Installing rfc3986-validator (0.1.1): Installing...
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3986-validator (0.1.1): Installing...
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3339-validator (0.1.4): Installing...
#   - Installing rfc3986-validator (0.1.1): Installing...
#   - Installing uri-template (1.3.0): Installing...
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3986-validator (0.1.1)
#   - Installing uri-template (1.3.0): Installing...
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Installing...
#   - Installing rfc3339-validator (0.1.4): Installing...
#   - Installing rfc3986-validator (0.1.1)
#   - Installing uri-template (1.3.0): Installing...
#   - Installing isoduration (20.11.0)
#   - Updating jupyter-client (6.1.12 -> 8.6.3): Installing...
#   - Installing rfc3339-validator (0.1.4): Installing...
#   - Installing rfc3986-validator (0.1.1)
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3986-validator (0.1.1)
#   - Installing uri-template (1.3.0): Installing...
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Installing uri-template (1.3.0): Installing...
#   - Installing uri-template (1.3.0)
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Installing uri-template (1.3.0)
#   - Updating jupyter-client (6.1.12 -> 8.6.3)
#   - Installing rfc3339-validator (0.1.4)
#   - Installing rfc3986-validator (0.1.1)
#   - Installing uri-template (1.3.0)
#   - Installing asttokens (3.0.0): Pending...
#   - Installing executing (2.2.0): Pending...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Pending...
#   - Installing python-json-logger (3.3.0): Pending...
#   - Installing python-json-logger (3.3.0): Pending...
#   - Installing pure-eval (0.2.3): Downloading... 0%
#   - Installing python-json-logger (3.3.0): Pending...
#   - Installing python-json-logger (3.3.0): Pending...
#   - Installing pure-eval (0.2.3): Downloading... 100%
#   - Installing python-json-logger (3.3.0): Pending...
#   - Installing python-json-logger (3.3.0): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Pending...
#   - Installing python-json-logger (3.3.0): Downloading... 0%
#   - Installing executing (2.2.0): Pending...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Downloading... 0%
#   - Installing asttokens (3.0.0): Downloading... 0%
#   - Installing executing (2.2.0): Pending...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Downloading... 0%
#   - Installing executing (2.2.0): Pending...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Downloading... 0%
#   - Installing asttokens (3.0.0): Downloading... 100%
#   - Installing executing (2.2.0): Pending...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Downloading... 0%
#   - Installing executing (2.2.0): Pending...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Downloading... 0%
#   - Installing asttokens (3.0.0): Installing...
#   - Installing executing (2.2.0): Pending...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Downloading... 0%
#   - Installing python-json-logger (3.3.0): Downloading... 100%
#   - Installing python-json-logger (3.3.0): Installing...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing executing (2.2.0): Downloading... 0%
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Installing...
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing executing (2.2.0): Downloading... 100%
#   - Downgrading packaging (24.2 -> 23.2): Pending...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Installing...
#   - Downgrading packaging (24.2 -> 23.2): Downloading... 0%
#   - Installing pure-eval (0.2.3): Installing...
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing executing (2.2.0): Downloading... 100%
#   - Downgrading packaging (24.2 -> 23.2): Downloading... 0%
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing asttokens (3.0.0)
#   - Installing executing (2.2.0): Downloading... 100%
#   - Downgrading packaging (24.2 -> 23.2): Downloading... 0%
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Downgrading packaging (24.2 -> 23.2): Downloading... 100%
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Downgrading packaging (24.2 -> 23.2): Installing...
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Downgrading packaging (24.2 -> 23.2): Installing...
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing executing (2.2.0): Installing...
#   - Downgrading packaging (24.2 -> 23.2): Installing...
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0): Installing...
#   - Installing python-json-logger (3.3.0)
#   - Downgrading packaging (24.2 -> 23.2): Installing...
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0)
#   - Installing executing (2.2.0)
#   - Downgrading packaging (24.2 -> 23.2): Installing...
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0)
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0)
#   - Downgrading packaging (24.2 -> 23.2)
#   - Installing pure-eval (0.2.3)
#   - Installing python-json-logger (3.3.0)
#   - Updating decorator (4.4.2 -> 5.2.1): Pending...
#   - Installing ipython-pygments-lexers (1.1.1): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-events (0.12.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing ipython-pygments-lexers (1.1.1): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-events (0.12.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Updating decorator (4.4.2 -> 5.2.1): Downloading... 0%
#   - Installing ipython-pygments-lexers (1.1.1): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-events (0.12.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-events (0.12.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing ipython-pygments-lexers (1.1.1): Downloading... 0%
#   - Installing jedi (0.19.2): Pending...
#   - Installing jupyter-events (0.12.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing jupyter-events (0.12.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing jupyter-events (0.12.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing ipython-pygments-lexers (1.1.1): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Updating decorator (4.4.2 -> 5.2.1): Downloading... 100%
#   - Installing ipython-pygments-lexers (1.1.1): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing ipython-pygments-lexers (1.1.1): Downloading... 100%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Pending...
#   - Installing overrides (7.7.0): Pending...
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Downloading... 0%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Downloading... 0%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 100%
#   - Installing jupyter-server-terminals (0.5.3): Downloading... 0%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Downloading... 100%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 100%
#   - Installing jupyter-server-terminals (0.5.3): Downloading... 100%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing ipython-pygments-lexers (1.1.1): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 100%
#   - Installing jupyter-server-terminals (0.5.3): Downloading... 100%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing ipython-pygments-lexers (1.1.1): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 100%
#   - Installing jupyter-server-terminals (0.5.3): Downloading... 100%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Updating decorator (4.4.2 -> 5.2.1): Installing...
#   - Installing ipython-pygments-lexers (1.1.1): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Downloading... 100%
#   - Installing jupyter-server-terminals (0.5.3): Downloading... 100%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Installing...
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing jupyter-server-terminals (0.5.3): Installing...
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Installing...
#   - Installing jupyter-server-terminals (0.5.3): Installing...
#   - Installing overrides (7.7.0): Downloading... 0%
#   - Installing overrides (7.7.0): Downloading... 100%
#   - Installing overrides (7.7.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Installing...
#   - Installing jupyter-server-terminals (0.5.3): Installing...
#   - Installing overrides (7.7.0): Installing...
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2): Downloading... 0%
#   - Installing jupyter-events (0.12.0): Installing...
#   - Installing jupyter-server-terminals (0.5.3): Installing...
#   - Installing overrides (7.7.0): Installing...
#   - Installing stack-data (0.6.3): Pending...
#   - Installing overrides (7.7.0): Installing...
#   - Installing stack-data (0.6.3): Pending...
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0): Installing...
#   - Installing stack-data (0.6.3): Pending...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Pending...
#   - Installing stack-data (0.6.3): Pending...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Pending...
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3): Pending...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Pending...
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3): Pending...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Pending...
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3): Pending...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Pending...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Downloading... 0%
#   - Updating urllib3 (2.4.0 -> 2.5.0): Downloading... 0%
#   - Installing stack-data (0.6.3): Downloading... 0%
#   - Updating urllib3 (2.4.0 -> 2.5.0): Downloading... 0%
#   - Updating urllib3 (2.4.0 -> 2.5.0): Downloading... 0%
#   - Installing stack-data (0.6.3): Downloading... 100%
#   - Updating urllib3 (2.4.0 -> 2.5.0): Downloading... 0%
#   - Updating urllib3 (2.4.0 -> 2.5.0): Downloading... 0%
#   - Installing stack-data (0.6.3): Installing...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Downloading... 0%
#   - Updating urllib3 (2.4.0 -> 2.5.0): Downloading... 100%
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3): Installing...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Installing jedi (0.19.2): Downloading... 100%
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3): Installing...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Installing stack-data (0.6.3)
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3)
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Installing jedi (0.19.2): Installing...
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3)
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3)
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Installing jedi (0.19.2)
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3)
#   - Updating urllib3 (2.4.0 -> 2.5.0): Installing...
#   - Updating urllib3 (2.4.0 -> 2.5.0)
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2)
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3)
#   - Updating urllib3 (2.4.0 -> 2.5.0)
#   - Updating decorator (4.4.2 -> 5.2.1)
#   - Installing ipython-pygments-lexers (1.1.1)
#   - Installing jedi (0.19.2)
#   - Installing jupyter-events (0.12.0)
#   - Installing jupyter-server-terminals (0.5.3)
#   - Installing overrides (7.7.0)
#   - Installing stack-data (0.6.3)
#   - Updating urllib3 (2.4.0 -> 2.5.0)
#   - Installing comm (0.2.2): Pending...
#   - Updating debugpy (1.8.0 -> 1.8.14): Pending...
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Pending...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Pending...
#   - Updating ipython (7.34.0 -> 9.3.0): Pending...
#   - Installing json5 (0.12.0): Pending...
#   - Installing json5 (0.12.0): Pending...
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Pending...
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Pending...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Pending...
#   - Installing json5 (0.12.0): Downloading... 0%
#   - Updating debugpy (1.8.0 -> 1.8.14): Pending...
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Pending...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 0%
#   - Installing comm (0.2.2): Downloading... 0%
#   - Updating debugpy (1.8.0 -> 1.8.14): Pending...
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Pending...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 0%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 100%
#   - Updating debugpy (1.8.0 -> 1.8.14): Pending...
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 100%
#   - Installing comm (0.2.2): Downloading... 100%
#   - Updating debugpy (1.8.0 -> 1.8.14): Pending...
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 100%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 100%
#   - Updating debugpy (1.8.0 -> 1.8.14): Downloading... 0%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Downloading... 100%
#   - Installing json5 (0.12.0): Installing...
#   - Updating debugpy (1.8.0 -> 1.8.14): Downloading... 0%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Installing...
#   - Installing comm (0.2.2): Installing...
#   - Updating debugpy (1.8.0 -> 1.8.14): Downloading... 0%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Installing...
#   - Updating debugpy (1.8.0 -> 1.8.14): Downloading... 0%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Installing...
#   - Installing comm (0.2.2)
#   - Updating debugpy (1.8.0 -> 1.8.14): Downloading... 0%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Installing...
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Pending...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Installing...
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Pending...
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Downloading... 100%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0): Installing...
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Pending...
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Pending...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Pending...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Pending...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Pending...
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Downloading... 0%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Pending...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Downloading... 0%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Pending...
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 0%
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Downloading... 0%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Pending...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Downloading... 100%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Downloading... 100%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Downloading... 100%
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Downloading... 100%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating debugpy (1.8.0 -> 1.8.14): Downloading... 40%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 50%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 100%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 100%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating debugpy (1.8.0 -> 1.8.14): Downloading... 100%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Downloading... 100%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 0%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 10%
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 10%
#   - Updating hf-xet (1.1.3 -> 1.1.4): Installing...
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 10%
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Installing...
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 10%
#   - Updating debugpy (1.8.0 -> 1.8.14): Installing...
#   - Updating fsspec (2025.3.2 -> 2025.5.1): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Installing...
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 10%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 20%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 30%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 40%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 50%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 60%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 70%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 80%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 90%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Downloading... 100%
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Pending...
#   - Updating psutil (5.9.5 -> 7.0.0): Downloading... 0%
#   - Updating psutil (5.9.5 -> 7.0.0): Downloading... 100%
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4): Installing...
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating fsspec (2025.3.2 -> 2025.5.1)
#   - Updating hf-xet (1.1.3 -> 1.1.4): Installing...
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating requests (2.32.3 -> 2.32.4): Pending...
#   - Updating requests (2.32.3 -> 2.32.4): Downloading... 0%
#   - Updating requests (2.32.3 -> 2.32.4): Downloading... 100%
#   - Updating requests (2.32.3 -> 2.32.4): Installing...
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating requests (2.32.3 -> 2.32.4): Installing...
#   - Updating hf-xet (1.1.3 -> 1.1.4)
#   - Updating ipython (7.34.0 -> 9.3.0): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating requests (2.32.3 -> 2.32.4): Installing...
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating requests (2.32.3 -> 2.32.4): Installing...
#   - Updating ipython (7.34.0 -> 9.3.0)
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating requests (2.32.3 -> 2.32.4): Installing...
#   - Updating fsspec (2025.3.2 -> 2025.5.1)
#   - Updating hf-xet (1.1.3 -> 1.1.4)
#   - Updating ipython (7.34.0 -> 9.3.0)
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating requests (2.32.3 -> 2.32.4): Installing...
#   - Updating debugpy (1.8.0 -> 1.8.14)
#   - Updating fsspec (2025.3.2 -> 2025.5.1)
#   - Updating hf-xet (1.1.3 -> 1.1.4)
#   - Updating ipython (7.34.0 -> 9.3.0)
#   - Installing json5 (0.12.0)
#   - Updating jupyter-server (1.16.0 -> 2.16.0)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86): Installing...
#   - Updating psutil (5.9.5 -> 7.0.0): Installing...
#   - Updating requests (2.32.3 -> 2.32.4): Installing...
#   - Updating requests (2.32.3 -> 2.32.4)
#   - Updating requests (2.32.3 -> 2.32.4)
#   - Updating psutil (5.9.5 -> 7.0.0)
#   - Updating requests (2.32.3 -> 2.32.4)
#   - Updating psutil (5.9.5 -> 7.0.0)
#   - Updating requests (2.32.3 -> 2.32.4)
#   - Updating nvidia-nvjitlink-cu12 (12.5.82 -> 12.9.86)
#   - Updating psutil (5.9.5 -> 7.0.0)
#   - Updating requests (2.32.3 -> 2.32.4)
#   - Installing async-lru (2.0.5): Pending...
#   - Updating ipykernel (6.17.1 -> 6.29.5): Pending...
#   - Installing jupyter-lsp (2.2.5): Pending...
#   - Installing jupyterlab-server (2.27.3): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Installing jupyterlab-server (2.27.3): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Updating ipykernel (6.17.1 -> 6.29.5): Pending...
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Installing async-lru (2.0.5): Downloading... 0%
#   - Updating ipykernel (6.17.1 -> 6.29.5): Pending...
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Updating ipykernel (6.17.1 -> 6.29.5): Downloading... 0%
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Updating ipykernel (6.17.1 -> 6.29.5): Downloading... 0%
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Installing async-lru (2.0.5): Downloading... 100%
#   - Updating ipykernel (6.17.1 -> 6.29.5): Downloading... 0%
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Updating ipykernel (6.17.1 -> 6.29.5): Downloading... 0%
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Installing async-lru (2.0.5): Installing...
#   - Updating ipykernel (6.17.1 -> 6.29.5): Downloading... 0%
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Pending...
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Updating ipykernel (6.17.1 -> 6.29.5): Downloading... 0%
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Installing async-lru (2.0.5)
#   - Updating ipykernel (6.17.1 -> 6.29.5): Downloading... 0%
#   - Installing jupyter-lsp (2.2.5): Downloading... 0%
#   - Installing jupyterlab-server (2.27.3): Downloading... 0%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Installing jupyterlab-server (2.27.3): Downloading... 100%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Installing jupyterlab-server (2.27.3): Downloading... 100%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Installing jupyter-lsp (2.2.5): Downloading... 100%
#   - Installing jupyterlab-server (2.27.3): Downloading... 100%
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Installing jupyterlab-server (2.27.3): Installing...
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Installing jupyter-lsp (2.2.5): Downloading... 100%
#   - Installing jupyterlab-server (2.27.3): Installing...
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Updating ipykernel (6.17.1 -> 6.29.5): Downloading... 100%
#   - Installing jupyter-lsp (2.2.5): Downloading... 100%
#   - Installing jupyterlab-server (2.27.3): Installing...
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Installing jupyterlab-server (2.27.3): Installing...
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
#   - Downgrading nvidia-cublas-cu12 (12.5.3.2 -> 12.1.3.1): Pending...
#   - Installing jupyter-lsp (2.2.5): Installing...
#   - Installing jupyterlab-server (2.27.3): Installing...
#   - Updating multidict (6.4.4 -> 6.5.0): Downloading... 0%
#   - Updating numpy (2.0.2 -> 2.3.0): Downloading... 0%
# ...
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1): Installing...
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Downloading... 100%
#   - Installing faiss-cpu (1.11.0): Downloading... 30%
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1): Installing...
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Downloading... 100%
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1): Installing...
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Installing faiss-cpu (1.11.0): Downloading... 50%
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1): Installing...
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Installing faiss-cpu (1.11.0): Downloading... 60%
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Pending...
#   - Downgrading typer (0.16.0 -> 0.9.4): Downloading... 0%
#   - Downgrading typer (0.16.0 -> 0.9.4): Downloading... 100%
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing faiss-cpu (1.11.0): Downloading... 80%
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing faiss-cpu (1.11.0): Downloading... 100%
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing faiss-cpu (1.11.0): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing faiss-cpu (1.11.0)
#   - Installing jupyter (1.1.1)
#   - Downgrading seaborn (0.13.2 -> 0.12.2): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0)
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0)
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Downgrading seaborn (0.13.2 -> 0.12.2)
#   - Downgrading sentence-transformers (4.1.0 -> 2.7.0)
#   - Installing torch-geometric (2.6.1)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2): Installing...
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4)
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4)
#   - Downgrading torchaudio (2.6.0+cu124 https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 2.1.2)
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2): Installing...
#   - Downgrading typer (0.16.0 -> 0.9.4)
#   - Downgrading typer (0.16.0 -> 0.9.4)
#   - Downgrading torchvision (0.21.0+cu124 https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl -> 0.16.2)
#   - Downgrading typer (0.16.0 -> 0.9.4)
#
# Writing lock file
#
# Installing the current project: insightspike-ai (0.8.0)Installing the current project: insightspike-ai (0.8.0)
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<string>", line 1, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<string>", line 1, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# Detected PyTorch 2.1.2 and CUDA 121. Installing PyG...
# Skipping virtualenv creation, as specified in config file.
# Skipping virtualenv creation, as specified in config file.
# Installation complete. Verifying libraries...
#   File "<string>", line 1
#     import torch; import faiss; import torch_geometric; print('✅ PyTorch version:', torch.__version__); print('✅ CUDA available for PyTorch:', torch.cuda.is_available()); print('✅ FAISS GPU enabled:', hasattr(faiss, 'GpuIndexIVFFlat')); print('✅ PyG version:', torch_geometric.__version__); print('\n🎉 Environment setup successful! A new, Colab-specific poetry.lock has been generated.'); print('📦 InsightSpike-AI package and all dependencies installed.'); print('🚀 CLI command "insightspike" is now available!')
# IndentationError: unexpected indent

# %%
# !pip list
# Out:
# Package                               Version             Editable project location
# ------------------------------------- ------------------- -------------------------
# absl-py                               1.4.0
# accelerate                            1.7.0
# aiofiles                              24.1.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.12.13
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.11.1
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arrow                                 1.3.0
# arviz                                 0.21.0
# astropy                               7.1.0
# astropy-iers-data                     0.2025.6.16.0.38.47
# asttokens                             3.0.0
# astunparse                            1.6.3
# async-lru                             2.0.5
# atpublic                              5.1
# attrs                                 25.3.0
# audioread                             3.0.1
# autograd                              1.8.0
# babel                                 2.17.0
# backcall                              0.2.0
# backports.tarfile                     1.2.0
# beautifulsoup4                        4.13.4
# betterproto                           2.0.0b6
# bigframes                             2.6.0
# bigquery-magics                       0.9.0
# bleach                                6.2.0
# blinker                               1.9.0
# blis                                  1.3.0
# blobfile                              3.0.0
# blosc2                                3.4.0
# bokeh                                 3.7.3
# Bottleneck                            1.4.2
# bqplot                                0.12.45
# branca                                0.8.1
# build                                 1.2.2.post1
# CacheControl                          0.14.3
# cachetools                            5.5.2
# catalogue                             2.0.10
# certifi                               2025.6.15
# cffi                                  1.17.1
# chardet                               5.2.0
# charset-normalizer                    3.4.2
# chex                                  0.1.89
# clarabel                              0.11.1
# cleo                                  2.1.0
# click                                 8.2.1
# cloudpathlib                          0.21.1
# cloudpickle                           3.1.1
# cmake                                 3.31.6
# cmdstanpy                             1.2.5
# colorcet                              3.1.0
# colorlover                            0.3.0
# colour                                0.1.5
# comm                                  0.2.2
# community                             1.0.0b1
# confection                            0.1.5
# cons                                  0.4.6
# contourpy                             1.3.2
# cramjam                               2.10.0
# crashtest                             0.4.1
# cryptography                          43.0.3
# cuda-python                           12.6.2.post1
# cudf-cu12                             25.2.1
# cudf-polars-cu12                      25.2.2
# cufflinks                             0.17.3
# cuml-cu12                             25.2.1
# cupy-cuda12x                          13.3.0
# curl_cffi                             0.11.3
# cuvs-cu12                             25.2.1
# cvxopt                                1.3.2
# cvxpy                                 1.6.6
# cycler                                0.12.1
# cyipopt                               1.5.0
# cymem                                 2.0.11
# Cython                                3.0.12
# dask                                  2024.12.1
# dask-cuda                             25.2.0
# dask-cudf-cu12                        25.2.2
# dask-expr                             1.1.21
# dataproc-spark-connect                0.7.5
# datascience                           0.17.6
# datasets                              2.14.4
# db-dtypes                             1.4.3
# dbus-python                           1.2.18
# debugpy                               1.8.14
# decorator                             5.2.1
# defusedxml                            0.7.1
# diffusers                             0.33.1
# dill                                  0.3.7
# distlib                               0.3.9
# distributed                           2024.12.1
# distributed-ucxx-cu12                 0.42.0
# distro                                1.9.0
# dlib                                  19.24.6
# dm-tree                               0.1.9
# docstring_parser                      0.16
# docutils                              0.21.2
# dopamine_rl                           4.1.2
# duckdb                                1.2.2
# dulwich                               0.22.8
# earthengine-api                       1.5.19
# easydict                              1.13
# editdistance                          0.8.1
# eerepr                                0.1.2
# einops                                0.8.1
# en_core_web_sm                        3.8.0
# entrypoints                           0.4
# et_xmlfile                            2.0.0
# etils                                 1.12.2
# etuples                               0.3.9
# executing                             2.2.0
# faiss-cpu                             1.11.0
# Farama-Notifications                  0.0.4
# fastai                                2.7.19
# fastapi                               0.115.12
# fastcore                              1.7.29
# fastdownload                          0.0.7
# fastjsonschema                        2.21.1
# fastprogress                          1.0.3
# fastrlock                             0.8.3
# ffmpy                                 0.6.0
# filelock                              3.18.0
# findpython                            0.6.3
# firebase-admin                        6.9.0
# Flask                                 3.1.1
# flatbuffers                           25.2.10
# flax                                  0.10.6
# folium                                0.19.7
# fonttools                             4.58.4
# fqdn                                  1.5.1
# frozendict                            2.4.6
# frozenlist                            1.7.0
# fsspec                                2025.5.1
# future                                1.0.0
# gast                                  0.6.0
# gcsfs                                 2025.3.2
# GDAL                                  3.8.4
# gdown                                 5.2.0
# geemap                                0.35.3
# geocoder                              1.38.1
# geographiclib                         2.0
# geopandas                             1.0.1
# geopy                                 2.4.1
# gin-config                            0.5.0
# gitdb                                 4.0.12
# GitPython                             3.1.44
# glob2                                 0.7
# google                                2.0.3
# google-ai-generativelanguage          0.6.15
# google-api-core                       2.25.1
# google-api-python-client              2.172.0
# google-auth                           2.38.0
# google-auth-httplib2                  0.2.0
# google-auth-oauthlib                  1.2.2
# google-cloud-aiplatform               1.97.0
# google-cloud-bigquery                 3.34.0
# google-cloud-bigquery-connection      1.18.3
# google-cloud-bigquery-storage         2.32.0
# google-cloud-core                     2.4.3
# google-cloud-dataproc                 5.20.0
# google-cloud-datastore                2.21.0
# google-cloud-firestore                2.21.0
# google-cloud-functions                1.20.4
# google-cloud-iam                      2.19.1
# google-cloud-language                 2.17.2
# google-cloud-resource-manager         1.14.2
# google-cloud-spanner                  3.55.0
# google-cloud-storage                  2.19.0
# google-cloud-translate                3.20.3
# google-colab                          1.0.0
# google-crc32c                         1.7.1
# google-genai                          1.20.0
# google-generativeai                   0.8.5
# google-pasta                          0.2.0
# google-resumable-media                2.7.2
# googleapis-common-protos              1.70.0
# googledrivedownloader                 1.1.0
# gradio                                5.31.0
# gradio_client                         1.10.1
# graphviz                              0.21
# greenlet                              3.2.3
# groovy                                0.1.2
# grpc-google-iam-v1                    0.14.2
# grpc-interceptor                      0.15.4
# grpcio                                1.73.0
# grpcio-status                         1.71.0
# grpclib                               0.4.8
# gspread                               6.2.1
# gspread-dataframe                     4.0.0
# gym                                   0.25.2
# gym-notices                           0.0.8
# gymnasium                             1.1.1
# h11                                   0.16.0
# h2                                    4.2.0
# h5netcdf                              1.6.1
# h5py                                  3.14.0
# hdbscan                               0.8.40
# hf_transfer                           0.1.9
# hf-xet                                1.1.4
# highspy                               1.11.0
# holidays                              0.74
# holoviews                             1.20.2
# hpack                                 4.1.0
# html5lib                              1.1
# httpcore                              1.0.9
# httpimport                            1.4.1
# httplib2                              0.22.0
# httpx                                 0.28.1
# huggingface-hub                       0.33.0
# humanize                              4.12.3
# hyperframe                            6.1.0
# hyperopt                              0.2.7
# ibis-framework                        9.5.0
# idna                                  3.10
# imageio                               2.37.0
# imageio-ffmpeg                        0.6.0
# imagesize                             1.4.1
# imbalanced-learn                      0.13.0
# immutabledict                         4.2.1
# importlib_metadata                    8.7.0
# importlib_resources                   6.5.2
# imutils                               0.5.4
# inflect                               7.5.0
# iniconfig                             2.1.0
# insightspike-ai                       0.8.0               /content/InsightSpike-AI
# installer                             0.7.0
# intel-cmplr-lib-ur                    2025.1.1
# intel-openmp                          2025.1.1
# ipyevents                             2.0.2
# ipyfilechooser                        0.6.0
# ipykernel                             6.29.5
# ipyleaflet                            0.20.0
# ipyparallel                           8.8.0
# ipython                               9.3.0
# ipython-genutils                      0.2.0
# ipython_pygments_lexers               1.1.1
# ipython-sql                           0.5.0
# ipytree                               0.2.2
# ipywidgets                            8.1.7
# isoduration                           20.11.0
# itsdangerous                          2.2.0
# jaraco.classes                        3.4.0
# jaraco.context                        6.0.1
# jaraco.functools                      4.1.0
# jax                                   0.5.2
# jax-cuda12-pjrt                       0.5.1
# jax-cuda12-plugin                     0.5.1
# jaxlib                                0.5.1
# jedi                                  0.19.2
# jeepney                               0.9.0
# jieba                                 0.42.1
# Jinja2                                3.1.6
# jiter                                 0.10.0
# joblib                                1.5.1
# json5                                 0.12.0
# jsonpatch                             1.33
# jsonpickle                            4.1.1
# jsonpointer                           3.0.0
# jsonschema                            4.24.0
# jsonschema-specifications             2025.4.1
# jupyter                               1.1.1
# jupyter_client                        8.6.3
# jupyter-console                       6.6.3
# jupyter_core                          5.8.1
# jupyter-events                        0.12.0
# jupyter_kernel_gateway                2.5.2
# jupyter-leaflet                       0.20.0
# jupyter-lsp                           2.2.5
# jupyter_server                        2.16.0
# jupyter_server_terminals              0.5.3
# jupyterlab                            4.4.3
# jupyterlab_pygments                   0.3.0
# jupyterlab_server                     2.27.3
# jupyterlab_widgets                    3.0.15
# jupytext                              1.17.2
# kaggle                                1.7.4.5
# kagglehub                             0.3.12
# keras                                 3.8.0
# keras-hub                             0.18.1
# keras-nlp                             0.18.1
# keyring                               25.6.0
# keyrings.google-artifactregistry-auth 1.1.2
# kiwisolver                            1.4.8
# langchain                             0.3.25
# langchain-core                        0.3.65
# langchain-text-splitters              0.3.8
# langcodes                             3.5.0
# langsmith                             0.3.45
# language_data                         1.3.0
# launchpadlib                          1.10.16
# lazr.restfulclient                    0.14.4
# lazr.uri                              1.0.6
# lazy_loader                           0.4
# libclang                              18.1.1
# libcudf-cu12                          25.2.1
# libcugraph-cu12                       25.2.0
# libcuml-cu12                          25.2.1
# libcuvs-cu12                          25.2.1
# libkvikio-cu12                        25.2.1
# libpysal                              4.13.0
# libraft-cu12                          25.2.0
# librosa                               0.11.0
# libucx-cu12                           1.18.1
# libucxx-cu12                          0.42.0
# lightgbm                              4.5.0
# linkify-it-py                         2.0.3
# llvmlite                              0.43.0
# locket                                1.0.0
# logical-unification                   0.4.6
# lxml                                  5.4.0
# Mako                                  1.1.3
# marisa-trie                           1.2.1
# Markdown                              3.8
# markdown-it-py                        3.0.0
# MarkupSafe                            3.0.2
# matplotlib                            3.10.3
# matplotlib-inline                     0.1.7
# matplotlib-venn                       1.1.2
# mdit-py-plugins                       0.4.2
# mdurl                                 0.1.2
# miniKanren                            1.0.3
# missingno                             0.5.2
# mistune                               3.1.3
# mizani                                0.13.5
# mkl                                   2025.0.1
# ml-dtypes                             0.4.1
# mlxtend                               0.23.4
# more-itertools                        10.7.0
# moviepy                               1.0.3
# mpmath                                1.3.0
# msgpack                               1.1.1
# multidict                             6.5.0
# multipledispatch                      1.0.0
# multiprocess                          0.70.15
# multitasking                          0.0.11
# murmurhash                            1.0.13
# music21                               9.3.0
# namex                                 0.1.0
# narwhals                              1.43.0
# natsort                               8.4.0
# nbclassic                             1.3.1
# nbclient                              0.10.2
# nbconvert                             7.16.6
# nbformat                              5.10.4
# ndindex                               1.10.0
# nest-asyncio                          1.6.0
# networkx                              3.5
# nibabel                               5.3.2
# nltk                                  3.9.1
# notebook                              7.4.3
# notebook_shim                         0.2.4
# numba                                 0.60.0
# numba-cuda                            0.2.0
# numexpr                               2.11.0
# numpy                                 2.3.0
# nvidia-cublas-cu12                    12.1.3.1
# nvidia-cuda-cupti-cu12                12.1.105
# nvidia-cuda-nvcc-cu12                 12.5.82
# nvidia-cuda-nvrtc-cu12                12.1.105
# nvidia-cuda-runtime-cu12              12.1.105
# nvidia-cudnn-cu12                     8.9.2.26
# nvidia-cufft-cu12                     11.0.2.54
# nvidia-curand-cu12                    10.3.2.106
# nvidia-cusolver-cu12                  11.4.5.107
# nvidia-cusparse-cu12                  12.1.0.106
# nvidia-cusparselt-cu12                0.6.2
# nvidia-ml-py                          12.575.51
# nvidia-nccl-cu12                      2.18.1
# nvidia-nvcomp-cu12                    4.2.0.11
# nvidia-nvjitlink-cu12                 12.9.86
# nvidia-nvtx-cu12                      12.1.105
# nvtx                                  0.2.12
# nx-cugraph-cu12                       25.2.0
# oauth2client                          4.1.3
# oauthlib                              3.2.2
# omegaconf                             2.3.0
# openai                                1.86.0
# opencv-contrib-python                 4.11.0.86
# opencv-python                         4.11.0.86
# opencv-python-headless                4.11.0.86
# openpyxl                              3.1.5
# opt_einsum                            3.4.0
# optax                                 0.2.5
# optree                                0.16.0
# orbax-checkpoint                      0.11.15
# orjson                                3.10.18
# osqp                                  1.0.4
# overrides                             7.7.0
# packaging                             23.2
# pandas                                2.3.0
# pandas-datareader                     0.10.0
# pandas-gbq                            0.29.1
# pandas-stubs                          2.2.2.240909
# pandocfilters                         1.5.1
# panel                                 1.7.1
# param                                 2.2.1
# parso                                 0.8.4
# parsy                                 2.1
# partd                                 1.4.2
# pathlib                               1.0.1
# patsy                                 1.0.1
# pbs-installer                         2025.6.12
# peewee                                3.18.1
# peft                                  0.15.2
# pexpect                               4.9.0
# pickleshare                           0.7.5
# pillow                                11.2.1
# pip                                   24.1.2
# pkginfo                               1.12.1.2
# platformdirs                          4.3.8
# plotly                                5.24.1
# plotnine                              0.14.5
# pluggy                                1.6.0
# ply                                   3.11
# poetry                                2.1.3
# poetry-core                           2.1.3
# polars                                1.21.0
# pooch                                 1.8.2
# portpicker                            1.5.2
# preshed                               3.0.10
# prettytable                           3.16.0
# proglog                               0.1.12
# progressbar2                          4.5.0
# prometheus_client                     0.22.1
# promise                               2.3
# prompt_toolkit                        3.0.51
# propcache                             0.3.2
# prophet                               1.1.7
# proto-plus                            1.26.1
# protobuf                              5.29.5
# psutil                                7.0.0
# psycopg2                              2.9.10
# ptyprocess                            0.7.0
# pure_eval                             0.2.3
# py-cpuinfo                            9.0.0
# py4j                                  0.10.9.7
# pyarrow                               18.1.0
# pyasn1                                0.6.1
# pyasn1_modules                        0.4.2
# pycairo                               1.28.0
# pycocotools                           2.0.10
# pycparser                             2.22
# pycryptodomex                         3.23.0
# pydantic                              2.11.7
# pydantic_core                         2.33.2
# pydata-google-auth                    1.9.1
# pydot                                 3.0.4
# pydotplus                             2.0.2
# PyDrive                               1.3.1
# PyDrive2                              1.21.3
# pydub                                 0.25.1
# pyerfa                                2.0.1.5
# pyg-lib                               0.4.0+pt21cu121
# pygame                                2.6.1
# pygit2                                1.18.0
# Pygments                              2.19.1
# PyGObject                             3.42.0
# PyJWT                                 2.10.1
# pylibcudf-cu12                        25.2.1
# pylibcugraph-cu12                     25.2.0
# pylibraft-cu12                        25.2.0
# pymc                                  5.23.0
# pymystem3                             0.2.0
# pynndescent                           0.5.13
# pynvjitlink-cu12                      0.6.0
# pynvml                                12.0.0
# pyogrio                               0.11.0
# pyomo                                 6.9.2
# PyOpenGL                              3.1.9
# pyOpenSSL                             24.2.1
# pyparsing                             3.2.3
# pyperclip                             1.9.0
# pyproj                                3.7.1
# pyproject_hooks                       1.2.0
# pyshp                                 2.3.1
# PySocks                               1.7.1
# pyspark                               3.5.1
# pytensor                              2.31.3
# pytest                                8.3.5
# python-apt                            0.0.0
# python-box                            7.3.2
# python-dateutil                       2.9.0.post0
# python-json-logger                    3.3.0
# python-louvain                        0.16
# python-multipart                      0.0.20
# python-slugify                        8.0.4
# python-snappy                         0.7.3
# python-utils                          3.9.1
# pytz                                  2025.2
# pyviz_comms                           3.0.5
# PyWavelets                            1.8.0
# PyYAML                                6.0.2
# pyzmq                                 27.0.0
# raft-dask-cu12                        25.2.0
# RapidFuzz                             3.13.0
# rapids-dask-dependency                25.2.0
# ratelim                               0.1.6
# referencing                           0.36.2
# regex                                 2024.11.6
# requests                              2.32.4
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# requirements-parser                   0.9.0
# rfc3339-validator                     0.1.4
# rfc3986-validator                     0.1.1
# rich                                  13.9.4
# rmm-cu12                              25.2.0
# roman-numerals-py                     3.1.0
# rpds-py                               0.25.1
# rpy2                                  3.5.17
# rsa                                   4.9.1
# ruff                                  0.11.13
# safehttpx                             0.1.6
# safetensors                           0.5.3
# scikit-image                          0.25.2
# scikit-learn                          1.7.0
# scipy                                 1.15.3
# scooby                                0.10.1
# scs                                   3.2.7.post2
# seaborn                               0.12.2
# SecretStorage                         3.3.3
# semantic-version                      2.10.0
# Send2Trash                            1.8.3
# sentence-transformers                 2.7.0
# sentencepiece                         0.2.0
# sentry-sdk                            2.30.0
# setproctitle                          1.3.6
# setuptools                            80.9.0
# shap                                  0.48.0
# shapely                               2.1.1
# shellingham                           1.5.4
# simple-parsing                        0.1.7
# simplejson                            3.20.1
# simsimd                               6.4.9
# six                                   1.17.0
# sklearn-compat                        0.1.3
# sklearn-pandas                        2.2.0
# slicer                                0.0.8
# smart-open                            7.1.0
# smmap                                 5.0.2
# sniffio                               1.3.1
# snowballstemmer                       3.0.1
# sortedcontainers                      2.4.0
# soundfile                             0.13.1
# soupsieve                             2.7
# soxr                                  0.5.0.post1
# spacy                                 3.8.7
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# spanner-graph-notebook                1.1.7
# Sphinx                                8.2.3
# sphinxcontrib-applehelp               2.0.0
# sphinxcontrib-devhelp                 2.0.0
# sphinxcontrib-htmlhelp                2.1.0
# sphinxcontrib-jsmath                  1.0.1
# sphinxcontrib-qthelp                  2.0.0
# sphinxcontrib-serializinghtml         2.0.0
# SQLAlchemy                            2.0.41
# sqlglot                               25.20.2
# sqlparse                              0.5.3
# srsly                                 2.5.1
# stack-data                            0.6.3
# stanio                                0.5.1
# starlette                             0.46.2
# statsmodels                           0.14.4
# stringzilla                           3.12.5
# stumpy                                1.13.0
# sympy                                 1.14.0
# tables                                3.10.2
# tabulate                              0.9.0
# tbb                                   2022.1.0
# tblib                                 3.1.0
# tcmlib                                1.3.0
# tenacity                              9.1.2
# tensorboard                           2.18.0
# tensorboard-data-server               0.7.2
# tensorflow                            2.18.0
# tensorflow-datasets                   4.9.9
# tensorflow_decision_forests           1.11.0
# tensorflow-hub                        0.16.1
# tensorflow-io-gcs-filesystem          0.37.1
# tensorflow-metadata                   1.17.1
# tensorflow-probability                0.25.0
# tensorflow-text                       2.18.1
# tensorstore                           0.1.74
# termcolor                             3.1.0
# terminado                             0.18.1
# text-unidecode                        1.3
# textblob                              0.19.0
# tf_keras                              2.18.0
# tf-slim                               1.1.0
# thinc                                 8.3.6
# threadpoolctl                         3.6.0
# tifffile                              2025.6.11
# tiktoken                              0.9.0
# timm                                  1.0.15
# tinycss2                              1.4.0
# tokenizers                            0.21.1
# toml                                  0.10.2
# tomlkit                               0.13.3
# toolz                                 0.12.1
# torch                                 2.1.2
# torch-geometric                       2.6.1
# torch-scatter                         2.1.2+pt21cu121
# torch-sparse                          0.6.18+pt21cu121
# torchao                               0.10.0
# torchaudio                            2.1.2
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.16.2
# tornado                               6.5.1
# tqdm                                  4.67.1
# traitlets                             5.14.3
# traittypes                            0.2.1
# transformers                          4.52.4
# treelite                              4.4.1
# treescope                             0.1.9
# triton                                2.1.0
# trove-classifiers                     2025.5.9.12
# tsfresh                               0.21.0
# tweepy                                4.15.0
# typeguard                             4.4.3
# typer                                 0.9.4
# types-python-dateutil                 2.9.0.20250516
# types-pytz                            2025.2.0.20250516
# types-setuptools                      80.9.0.20250529
# typing_extensions                     4.14.0
# typing-inspection                     0.4.1
# tzdata                                2025.2
# tzlocal                               5.3.1
# uc-micro-py                           1.0.3
# ucx-py-cu12                           0.42.0
# ucxx-cu12                             0.42.0
# umap-learn                            0.5.7
# umf                                   0.10.0
# uri-template                          1.3.0
# uritemplate                           4.2.0
# urllib3                               2.5.0
# uvicorn                               0.34.3
# vega-datasets                         0.9.0
# virtualenv                            20.31.2
# wadllib                               1.3.6
# wandb                                 0.20.1
# wasabi                                1.1.3
# wcwidth                               0.2.13
# weasel                                0.4.1
# webcolors                             24.11.1
# webencodings                          0.5.1
# websocket-client                      1.8.0
# websockets                            15.0.1
# Werkzeug                              3.1.3
# wheel                                 0.45.1
# widgetsnbextension                    4.0.14
# wordcloud                             1.9.4
# wrapt                                 1.17.2
# wurlitzer                             3.1.1
# xarray                                2025.3.1
# xarray-einstats                       0.9.0
# xgboost                               2.1.4
# xlrd                                  2.0.2
# xxhash                                3.5.0
# xyzservices                           2025.4.0
# yarl                                  1.20.1
# ydf                                   0.12.0
# yellowbrick                           1.5
# yfinance                              0.2.63
# zict                                  3.0.0
# zipp                                  3.23.0
# zstandard                             0.23.0

# %%
# Package diagnostics
print(f"\n📦 Package Diagnostics:")
critical_packages = [
    'torch', 'torch_geometric', 'faiss', 'sentence_transformers',
    'networkx', 'transformers', 'numpy', 'sklearn'  # scikit_learn → sklearn に修正
]

installed_packages = []
missing_packages = []

for package in critical_packages:
    try:
        if package == 'sklearn':
            import sklearn
            version = sklearn.__version__
            package_name = 'scikit-learn'
        elif package == 'sentence_transformers':
            import sentence_transformers
            version = sentence_transformers.__version__
            package_name = 'sentence_transformers'
        elif package == 'faiss':
            import faiss
            version = getattr(faiss, '__version__', 'unknown')
            package_name = 'faiss'
        elif package == 'torch_geometric':
            import torch_geometric
            version = torch_geometric.__version__
            package_name = 'torch_geometric'
        else:
            module = __import__(package)
            version = getattr(module, '__version__', 'unknown')
            package_name = package

        print(f"   ✅ {package_name}: {version}")
        installed_packages.append(package_name)
    except ImportError as e:
        print(f"   ❌ {package}: Not installed ({str(e)[:30]}...)")
        missing_packages.append(package)

# Project structure check
print(f"\n📁 Project Structure:")
structure_checks = [
    ('InsightSpike source code', 'src/insightspike'),
    ('core/ module', 'src/insightspike/core'),
    ('utils/ module', 'src/insightspike/utils'),
    ('agents/ module', 'src/insightspike/agents')
]

structure_ok = 0
for name, path in structure_checks:
    if os.path.exists(path):
        print(f"   ✅ {name} found")
        structure_ok += 1
    else:
        print(f"   ❌ {name} missing")

# Summary
print(f"\n{'='*50}")
print(f"📊 SUMMARY:")
print(f"   Installed: {len(installed_packages)}/{len(critical_packages)} packages")
if missing_packages:
    print(f"   Missing: {len(missing_packages)} packages")

# Recommendations
if missing_packages or structure_ok < len(structure_checks):
    print(f"\n🔧 RECOMMENDED ACTIONS:")
    if missing_packages:
        print(f"   1. Install missing packages: {', '.join(missing_packages)}")
    if structure_ok < len(structure_checks):
        print(f"   2. Check project directory structure")
    print(f"   3. Re-run setup script if needed")
    print(f"   4. Check troubleshooting section above for specific solutions")

print(f"\n🚀 QUICK ACTIONS:")
print(f"   • Restart Runtime: Runtime > Restart Runtime")
print(f"   • Re-run Setup: Execute cells 1-3 in order")
if missing_packages:
    print(f"   • Manual Fix: Use troubleshooting commands above")

print(f"\n{'='*50}")
# Out:
# 📦 Package Diagnostics:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     new_config.merge(self.cli_config)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.init_gui_pylab()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     # are processed before we enter the eventloop, even if the previous dispatch was
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     # Only abort execute requests
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     return metadata
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     run_cell = shell.run_cell_async
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     self._data_pub = self.data_pub_class(parent=self)  # type:ignore[has-type]
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     try:
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     if any(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     attr = getattr(self._obj, key)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     return result
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     for transform in self.input_transformers_post:
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#   File "/tmp/ipython-input-3-142045422.py", line 30, in <cell line: 0>
#     module = __import__(package)
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
#    ✅ torch: 2.1.2+cu121
#    ✅ torch_geometric: 2.6.1
#    ✅ faiss: 1.11.0
#    ❌ sentence_transformers: Not installed
#    ✅ networkx: 3.5
#    ✅ transformers: 4.52.4
#    ✅ numpy: 2.0.2
#    ❌ sklearn: Not installed
#
# 📁 Project Structure:
#    ✅ InsightSpike source code found
#    ✅ core/ module found
#    ✅ utils/ module found
#    ❌ agents/ module missing
#
# ==================================================
# 📊 SUMMARY:
#    Installed: 6/8 packages
#    Missing: 2 packages
#
# 🔧 RECOMMENDED ACTIONS:
#    1. Install missing packages: sentence_transformers, sklearn
#    2. Check project directory structure
#    3. Re-run setup script if needed
#    4. Check troubleshooting section above for specific solutions
#
# 🚀 QUICK ACTIONS:
#    • Restart Runtime: Runtime > Restart Runtime
#    • Re-run Setup: Execute cells 1-3 in order
#    • Manual Fix: Use troubleshooting commands above
#
# ==================================================

# %%
import sys
import os
import platform
import subprocess

print("🔍 InsightSpike-AI System Diagnostic")
print("=" * 50)

# Environment info
print(f"🐍 Python: {sys.version}")
print(f"💻 Platform: {platform.platform()}")
print(f"📂 Working Dir: {os.getcwd()}")

# Check if in Colab
try:
    import google.colab
    print("☁️  Environment: Google Colab ✅")
    in_colab = True
except ImportError:
    print("💻 Environment: Local/Other")
    in_colab = False

# Memory info
try:
    import psutil
    memory = psutil.virtual_memory()
    print(f"💾 RAM: {memory.total / 1e9:.1f} GB total, {memory.available / 1e9:.1f} GB available")
except ImportError:
    print("💾 RAM: Memory info not available")

# GPU info with detailed status
try:
    import torch
    print(f"\n🎮 GPU Status:")
    print(f"   PyTorch: {torch.__version__}")
    print(f"   CUDA Available: {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"   GPU: {torch.cuda.get_device_name(0)}")
        print(f"   GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
        print(f"   CUDA Version: {torch.version.cuda}")
    else:
        print("   Mode: CPU only (fully functional)")
except ImportError:
    print("\n🎮 PyTorch: Not installed ❌")

# Configuration check
print(f"\n⚙️  Configuration Status:")
try:
    from src.insightspike.core.config import LLMConfig
    config = LLMConfig()
    print(f"   ✅ LLM Model: {config.model_name}")
    print(f"   ✅ Temperature: {config.temperature}")
except Exception as e:
    print(f"   ❌ Configuration error: {str(e)[:50]}...")

# Package diagnostics - 修正版
print(f"\n📦 Package Diagnostics:")
critical_packages = [
    'torch', 'torch_geometric', 'faiss', 'sentence_transformers',
    'networkx', 'transformers', 'numpy', 'sklearn'  # scikit_learn → sklearn に修正
]

installed_packages = []
missing_packages = []

for package in critical_packages:
    try:
        if package == 'sklearn':  # scikit_learn → sklearn に修正
            import sklearn
            version = sklearn.__version__
            package_name = 'scikit-learn'  # 表示名も修正
        elif package == 'sentence_transformers':
            import sentence_transformers
            version = sentence_transformers.__version__
            package_name = 'sentence_transformers'
        elif package == 'faiss':
            import faiss
            version = getattr(faiss, '__version__', 'unknown')
            package_name = 'faiss'
        elif package == 'torch_geometric':
            import torch_geometric
            version = torch_geometric.__version__
            package_name = 'torch_geometric'
        else:
            module = __import__(package)
            version = getattr(module, '__version__', 'unknown')
            package_name = package

        print(f"   ✅ {package_name}: {version}")
        installed_packages.append(package_name)
    except ImportError:
        print(f"   ❌ {package}: Not installed")
        missing_packages.append(package)

# Directory structure check
print(f"\n📁 Project Structure:")
if os.path.exists('src/insightspike'):
    print("   ✅ InsightSpike source code found")
    src_contents = os.listdir('src/insightspike')
    key_modules = ['core', 'utils', 'agents']
    for module in key_modules:
        if module in src_contents:
            print(f"   ✅ {module}/ module present")
        else:
            print(f"   ❌ {module}/ module missing")
else:
    print("   ❌ InsightSpike source code not found")
    print("       💡 Make sure you're in the correct directory")

# Summary and recommendations
print(f"\n" + "=" * 50)
print(f"📊 SUMMARY:")
print(f"   Installed: {len(installed_packages)}/{len(critical_packages)} packages")
print(f"   Missing: {len(missing_packages)} packages")

if missing_packages:
    print(f"\n🔧 RECOMMENDED ACTIONS:")
    if 'torch_geometric' in missing_packages:
        print("   1. Install PyTorch Geometric: Re-run Step 2 dependency cell")
    if 'faiss' in missing_packages:
        print("   2. Install FAISS: !pip install faiss-gpu")
    if len(missing_packages) > 2:
        print("   3. Complete reinstall: Restart runtime, re-run all setup cells")
    print("   4. Check troubleshooting section above for specific solutions")
else:
    print(f"\n🎉 SYSTEM STATUS: Ready for research!")
    print(f"   All critical packages installed")
    print(f"   InsightSpike-AI is fully functional")

# Quick action buttons for Colab
if in_colab:
    print(f"\n🚀 QUICK ACTIONS:")
    print(f"   • Restart Runtime: Runtime > Restart Runtime")
    print(f"   • Re-run Setup: Execute cells 1-3 in order")
    print(f"   • Manual Fix: Use troubleshooting commands above")

print(f"\n" + "=" * 50)
# Out:
# 🔍 InsightSpike-AI System Diagnostic
# ==================================================
# 🐍 Python: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# 💻 Platform: Linux-6.1.123+-x86_64-with-glibc2.35
# 📂 Working Dir: /content/InsightSpike-AI
# ☁️  Environment: Google Colab ✅
# 💾 RAM: 13.6 GB total, 11.9 GB available
#
# 🎮 GPU Status:
#    PyTorch: 2.1.2+cu121
#    CUDA Available: True
#    GPU: Tesla T4
#    GPU Memory: 15.8 GB
#    CUDA Version: 12.1
#
# ⚙️  Configuration Status:
# WARNING:src.insightspike.core.agents.main_agent:Graph reasoner (Layer 3) not available - requires PyTorch
#    ✅ LLM Model: TinyLlama/TinyLlama-1.1B-Chat-v1.0
#    ✅ Temperature: 0.3
#
# 📦 Package Diagnostics:
#    ✅ torch: 2.1.2+cu121
#    ✅ torch_geometric: 2.6.1
#    ✅ faiss: 1.11.0
#    ❌ sentence_transformers: Not installed
#    ✅ networkx: 3.5
#    ✅ transformers: 4.52.4
#    ✅ numpy: 2.0.2
#    ❌ scikit_learn: Not installed
#
# 📁 Project Structure:
#    ✅ InsightSpike source code found
#    ✅ core/ module present
#    ✅ utils/ module present
#    ❌ agents/ module missing
#
# ==================================================
# 📊 SUMMARY:
#    Installed: 6/8 packages
#    Missing: 2 packages
#
# 🔧 RECOMMENDED ACTIONS:
#    4. Check troubleshooting section above for specific solutions
#
# 🚀 QUICK ACTIONS:
#    • Restart Runtime: Runtime > Restart Runtime
#    • Re-run Setup: Execute cells 1-3 in order
#    • Manual Fix: Use troubleshooting commands above
#
# ==================================================

# %%
# NumPy互換性問題を環境変数で回避し、CLIテストを簡潔にする

# NumPy互換性警告を環境変数で抑制
import os
os.environ['NUMPY_WARN_NO_ARRAY_API'] = '1'

print("Testing InsightSpike CLI availability...")

# CLIの基本動作確認
try:
    result = !insightspike 2>&1
    if "Usage:" in " ".join(result):
        print("✅ InsightSpike CLI is available!")
        print("✅ CLI command 'insightspike' works!")
        
        # 利用可能なコマンド表示
        print("\n📋 CLI Status:")
        # !insightspike
        
    else:
        print("❌ CLI not working properly")
        print("Output:", " ".join(result))
        
except Exception as e:
    print(f"❌ CLI test failed: {e}")

# Python モジュールとしてのテスト
print("\n🐍 Testing Python module import...")
try:
    import sys
    sys.path.insert(0, '/content/InsightSpike-AI/src')
    
    # 基本的なimportテスト
    from insightspike.core.config import LLMConfig
    print("✅ Core modules can be imported")
    
    config = LLMConfig()
    print(f"✅ Configuration loaded: {config.model_name}")
    
except Exception as e:
    print(f"❌ Module import failed: {e}")
    print("💡 This might be due to NumPy compatibility issues")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-3012406383.py in <cell line: 0>()
#       1 # InsightSpike CLIが利用可能か確認
# ----> 2 insightspike --help
#       3 insightspike --version
#       4
#
# NameError: name 'insightspike' is not defined

# %%
import sys
import torch

print(f"Python version: {sys.version}")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
# Out:
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# PyTorch version: 2.1.2+cu121
# CUDA available: True
# CUDA version: 12.1
# GPU name: Tesla T4
